# %%
import xml.etree.ElementTree as et
tree = et.ElementTree(file='menu.xml')
root = tree.getroot()

print(root.tag)
# Out:
# menu

# %%
type(root)
# Out:
# xml.etree.ElementTree.Element

# %%
for child in root:
    print('tag:', child.tag, 'attributes:', child.attrib)
    for grandchild in child:
        print('\ttag:', grandchild.tag, 'attributes:', grandchild.attrib)
# Out:
# tag: breakfast attributes: {'hours': '7-11'}
# 	tag: item attributes: {'price': '$6.00'}
# 	tag: item attributes: {'price': '$4.00'}
# tag: lunch attributes: {'hours': '11-3'}
# 	tag: item attributes: {'price': '$5.00'}
# tag: dinner attributes: {'hours': '3-10'}
# 	tag: item attributes: {'price': '8.00'}

# %%
len(root)
# Out:
# 3

# %%
len(root[0])
# Out:
# 2

# %%
print(root[0])
# Out:
# <Element 'breakfast' at 0x000001662BAEDE40>

# %%
print(root[0].get("hours"))
# Out:
# 7-11

# %%
print(root[0].keys())
# Out:
# ['hours']

# %%
print(root[0].items())
# Out:
# [('hours', '7-11')]

# %%
lunch = root.find("lunch")
print(lunch)
print(lunch.get("hours"))
print(lunch.keys())
print(lunch.items())
# Out:
# <Element 'lunch' at 0x000001662BAEEED0>
# 11-3
# ['hours']
# [('hours', '11-3')]

# %%
type(lunch)
# Out:
# xml.etree.ElementTree.Element

# %%
print(root[0].findall('item'))

for item in root[0].findall('item'):
    print(item.get('price'))
    print(item.text)
# Out:
# [<Element 'item' at 0x000001662BAEEE30>, <Element 'item' at 0x000001662BAEEE80>]
# $6.00
# breakfast burritos
# $4.00
# pancakes

# %%
print(root[0].findall('item'))
# Out:
# [<Element 'item' at 0x000001662BAEEE30>, <Element 'item' at 0x000001662BAEEE80>]

# %%
import json
j1 = {"name":"홍길동", "birth":"0525", "age": 30}

# %%
j1
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
json.dumps(j1)
# Out:
# '{"name": "\\ud64d\\uae38\\ub3d9", "birth": "0525", "age": 30}'

# %%
print(json.dumps(j1, indent=2))
{
"age": 30,
"birth": "0525",
"name":"\ubc15\uc751\uc6a9"
}
# Out:
# {
#   "name": "\ud64d\uae38\ub3d9",
#   "birth": "0525",
#   "age": 30
# }
# {'age': 30, 'birth': '0525', 'name': '박응용'}

# %%
json.dumps([1,2,3])
# Out:
# '[1, 2, 3]'

# %%
json.dumps((4,5,6))
# Out:
# '[4, 5, 6]'

# %%
j1 = {"name":"홍길동", "birth":"0525", "age": 30}

# %%
d1 = json.dumps(j1)

# %%
json.loads(d1)
# Out:
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
# %%writefile myinfo.json
# {
#     "name": "홍길동",
#     "birth": "0525",
#     "age": 30
# }
# Out:
# Overwriting myinfo.json

# %%
import json

with open('./myinfo.json', encoding='utf-8') as f:
    data = json.load(f)

print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'name': '홍길동', 'birth': '0525', 'age': 30}

# %%
from urllib.request import urlopen
html = urlopen("http://pythonscraping.com/pages/page1.html")
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
from urllib.request import urlopen
html = urlopen("http://pythonscraping.com/pages/page1.html")
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://pythonscraping.com/pages/page1.html")
bsObj = BeautifulSoup(html.read(), "html.parser")
print(bsObj.h1)
# Out:
# <h1>An Interesting Title</h1>

# %%
from bs4 import BeautifulSoup

html = """
<html>
<head>
<title>A Useful Page</title>
</head>
<body>
<h1>An Interesting Title</h1>
<div>Lorem ipsum dolor sit amet</div>
</body>
</html>
"""

bsObj = BeautifulSoup(html, "html.parser")

print(bsObj.h1)
print(bsObj.h1.text)
# Out:
# <h1>An Interesting Title</h1>
# An Interesting Title
